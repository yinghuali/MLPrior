# %%
import pandas as pd

# %%
df = pd.read_csv('data/adult.csv')

dic_race = {'Amer-Indian-Eskimo': 'White', 'Asian-Pac-Islander': 'White', 
            'Black': 'White', 'Other': 'White', 'White': 'Black'}
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df_race = df.copy()
df_race['race'] = [dic_race[i] for i in df['race']]
df_race.to_csv("data/fairness_race.csv",index=False,sep=',')
df_race.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  White    Male             0             0
# 1    Farming-fishing      Husband  Black    Male             0             0
# 2    Protective-serv      Husband  Black    Male             0             0
# 3  Machine-op-inspct      Husband  White    Male          7688             0
# 4                  ?    Own-child  Black  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df_gender = df.copy()
dic_gender = {'Female': 'Male', 'Male': 'Female'}
df_gender['gender'] = [dic_gender[i] for i in df['gender']]
df_gender.to_csv("data/fairness_gender.csv",index=False,sep=',')
df_gender.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black  Female             0             0
# 1    Farming-fishing      Husband  White  Female             0             0
# 2    Protective-serv      Husband  White  Female             0             0
# 3  Machine-op-inspct      Husband  Black  Female          7688             0
# 4                  ?    Own-child  White    Male             0             0
#
#    hours-per-week native-country income
# ...

# %%
def udf_age(i):
    if 18<=i<=29:
        return 65
    if i >= 30:
        return 25
    
df = pd.read_csv('data/bank.csv')
df['age'] = df['age'].apply(udf_age)
df.to_csv("data/fairness_age.csv",index=False,sep=',')
